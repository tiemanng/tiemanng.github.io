# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.32.5)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.12.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pygithub->getorg) (2.6.3)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (3.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.9.25/x64/lib/python3.9/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.4.22)
# Downloading python_frontmatter-1.1.0-py3-none-any.whl (9.8 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.1.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Die Determinanten von Parteiensystemen<br />Konferenz 'Parteien und Parteiensysteme in Osteuropa', Andrassy Universität Budapest; Budapest, Hungary Budapest, Közép-Magyarország, Magyarország
# Static and Dynamic Perspectives on Party System Nationalization in Postcommunist Eastern Europe<br />Joint Sessions of Workshops (ECPR), University of Rennes and Institut d'Etudes Politiques de Rennes; Rennes, France Rennes, Ille-et-Vilaine, Bretagne, France métropolitaine, France
# Projection and Bias<br />26th International Conference of Europeanists, Council for European Studies (CES); Madrid, Spain Madrid, Comunidad de Madrid, España
# Choosing Policy, Compensating Consensus, or Pushing for Change?<br />70th Annual Conference of the Midwest Political Science Association (MPSA); Chicago, IL, USA Chicago, South Chicago Township, Cook County, Illinois, United States
# Proximity and Directional Voting in EP Elections<br />Fifth Pan-European Conference on EU Politics, University of Porto; Porto, Portugal Porto, Portugal
# Alienation or Indifference? Determinants of Voter Abstention in Elections to the European Parliament<br />70th Annual Conference of the Midwest Political Science Association (MPSA); Chicago, IL, USA Chicago, South Chicago Township, Cook County, Illinois, United States
# Die Debatte zum European Political Space und die Dynamik von euroskeptischen Orientierungen in der EU-27<br />Gastvortrag, Max-Planck-Institut für Gesellschaftsforschung (MPIfG), Cologne; Cologne, Germany Köln, Nordrhein-Westfalen, Deutschland
# Room to Manoeuvre? Party Strategies in the European Political Space<br />EPOP 2014 Conference; Edinburgh, United Kingdom City of Edinburgh, Alba / Scotland, United Kingdom
# Projection and Bias: A Simulation Study<br />Biennial Conference of the European Union Studies Association (EUSA); Baltimore, MD, USA Baltimore, Maryland, United States
# Advanced Regression Modelling Using Stata: Time-Series-Cross-Section and Multilevel Models<br />Blockseminar, Max-Planck-Institut für Gesellschaftsforschung (MPIfG); Cologne, Germany Köln, Nordrhein-Westfalen, Deutschland
# The Economy and the Vote in Elections to the European Parliament<br />Biennial Conference of the European Union Studies Association (EUSA); Los Angeles, CA, USA Los Angeles, Los Angeles County, California, United States
# The Electoral Consequences of Party Ambiguity and Voter Uncertainty<br />Conference on Decision Sciences, Graduate School for Decision Sciences (GSDS), Universität Konstanz; Constance, Germany Konstanz, VVG der Stadt Konstanz, Landkreis Konstanz, Baden-Württemberg, Deutschland
# A Unified Model of EP Elections<br />Biennial Conference of the European Union Studies Association (EUSA); Boston, MA, USA Boston, Suffolk County, Massachusetts, United States
# The Nationalization of East European Party Systems<br />Third General Conference of the ECPR, Corvinus University Budapest; Budapest, Hungary Budapest, Közép-Magyarország, Magyarország
# Bindende Obergrenzen? Strategische Koordination in westeuropäischen Demokratien<br />Tag der Politikwissenschaft, Universität Graz; Graz, Austria Graz, Steiermark, Österreich
# Ambiguity, Uncertainty, Risk, and Vote Choice<br />New Developments in Spatial Models of Party Competition, Interdisciplinary Workshop, Universität Konstanz; Constance, Germany Konstanz, VVG der Stadt Konstanz, Landkreis Konstanz, Baden-Württemberg, Deutschland
# Die Konsequenzen der Mehrheitswahl: Zur Reform des Österreichischen Wahlsystems<br />Tag der Politikwissenschaft, Universität Salzburg; Salzburg, Austria Salzburg, 5020, Österreich
# Strategic Entry and Strategic Voting: Evidence from the District Level<br />73rd Annual Conference of the Midwest Political Science Association (MPSA); Chicago, IL, USA Chicago, South Chicago Township, Cook County, Illinois, United States
# Voter Uncertainty and Party Ambiguity in EP Elections<br />Dreiländertagung von DVPW, ÖGPW und SVPW; Heidelberg, Germany Heidelberg, Baden-Württemberg, Deutschland
# Comparative Statics of Projection Effects: Simulating Assimilation and Contrast<br />Sixth Pan-European Conference on EU Politics, University of Tampere; Tampere, Finland Tampere, Tampereen seutukunta, Pirkanmaa, Manner-Suomi, Suomi / Finland
# An unhandled exception occurred while processing input Vienna, Austria with message Non-successful status code 429
# An unhandled exception occurred while processing input Edinburgh, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input New Orleans, LA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input New Orleans, LA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Milan, Italy with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Reykjavik, Iceland with message Non-successful status code 429
# An unhandled exception occurred while processing input Brussels, Belgium with message Non-successful status code 429
# An unhandled exception occurred while processing input Aberdeen, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input San Francisco, CA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Austin, TX, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Lüneburg, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Berlin, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Lüneburg, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Glasgow, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Vienna, Austria with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Edinburgh, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Osnabrück, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input New Orleans, LA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Hamburg, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Vienna, Austria with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Washington, DC, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Innsbruck, Austria with message Non-successful status code 429
# An unhandled exception occurred while processing input Budapest, Hungary with message Non-successful status code 429
# An unhandled exception occurred while processing input Cambridge, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Berlin, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Boston, MA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Tutzing, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Brussels, Belgium with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Lisbon, Portugal with message Non-successful status code 429
# An unhandled exception occurred while processing input Pisa, Italy with message Non-successful status code 429
# An unhandled exception occurred while processing input Edinburgh, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Riga, Latvia with message Non-successful status code 429
# An unhandled exception occurred while processing input Budapest, Hungary with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Dublin, Ireland with message Non-successful status code 429
# An unhandled exception occurred while processing input Greifswald, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Frankfurt (Oder), Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Boston, MA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Madrid, Spain with message Non-successful status code 429
# An unhandled exception occurred while processing input Rostock, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Lüneburg, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Constance, Germany with message Non-successful status code 429
# An unhandled exception occurred while processing input Chicago, IL, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Cardiff, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Mannheim, Germany with message Non-successful status code 429

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
